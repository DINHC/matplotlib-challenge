# %% [markdown]
# ## Observations and Insights

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset

combined_df = pd.merge(mouse_metadata, study_results, how="inner", on="Mouse ID")

# Display the data table for preview
combined_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice.
total_mice = combined_df["Mouse ID"].count()
total_mice
# Out:
# 1893

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
duplicate_ID = combined_df[combined_df.duplicated(['Mouse ID', 'Timepoint'])]
duplicate_ID
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 909     g989     Propriva  Female          21          26          0
# 911     g989     Propriva  Female          21          26          5
# 913     g989     Propriva  Female          21          26         10
# 915     g989     Propriva  Female          21          26         15
# 917     g989     Propriva  Female          21          26         20
#
#      Tumor Volume (mm3)  Metastatic Sites
# 909           45.000000                 0
# 911           47.570392                 0
# 913           49.880528                 0
# 915           53.442020                 0
# 917           54.657650                 1

# %%
# Optional: Get all the data for the duplicate mouse ID. 
duplicate_rows = combined_df[combined_df.duplicated(['Mouse ID',])]
duplicate_rows
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# 5        k403     Ramicane  Male          21          16         25
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 1              38.825898                 0
# 2              35.014271                 1
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_data = combined_df.drop_duplicates("Mouse ID")
clean_data
# Out:
#      Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane    Male          21          16          0
# 10       s185    Capomulin  Female           3          17          0
# 20       x401    Capomulin  Female          16          15          0
# 30       m601    Capomulin    Male          22          17          0
# 40       g791     Ramicane    Male          11          16          0
# ...       ...          ...     ...         ...         ...        ...
# 1858     z314     Stelasyn  Female          21          28          0
# 1860     z435     Propriva  Female          12          26          0
# 1863     z581    Infubinol  Female          24          25          0
# 1873     z795     Naftisol  Female          13          29          0
# 1883     z969     Naftisol    Male           9          30          0
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0                   45.0                 0
# ...

# %%
# Checking the number of mice in the clean DataFrame.
clean_tm = clean_data["Mouse ID"].count()
clean_tm
# Out:
# 249

# %%
mean = combined_df.groupby('Drug Regimen')['Tumor Volume (mm3)'].mean()
mean
# Out:
# Drug Regimen
# Capomulin    40.675741
# Ceftamin     52.591172
# Infubinol    52.884795
# Ketapril     55.235638
# Naftisol     54.331565
# Placebo      54.033581
# Propriva     52.322552
# Ramicane     40.216745
# Stelasyn     54.233149
# Zoniferol    53.236507
# Name: Tumor Volume (mm3), dtype: float64

# %%
median = combined_df.groupby('Drug Regimen')['Tumor Volume (mm3)'].median()
median
# Out:
# Drug Regimen
# Capomulin    41.557809
# Ceftamin     51.776157
# Infubinol    51.820584
# Ketapril     53.698743
# Naftisol     52.509285
# Placebo      52.288934
# Propriva     50.854632
# Ramicane     40.673236
# Stelasyn     52.431737
# Zoniferol    51.818479
# Name: Tumor Volume (mm3), dtype: float64

# %%
variance = combined_df.groupby('Drug Regimen')['Tumor Volume (mm3)'].var()
variance
# Out:
# Drug Regimen
# Capomulin    24.947764
# Ceftamin     39.290177
# Infubinol    43.128684
# Ketapril     68.553577
# Naftisol     66.173479
# Placebo      61.168083
# Propriva     42.351070
# Ramicane     23.486704
# Stelasyn     59.450562
# Zoniferol    48.533355
# Name: Tumor Volume (mm3), dtype: float64

# %%
standard= combined_df.groupby('Drug Regimen')['Tumor Volume (mm3)'].std()
standard
# Out:
# Drug Regimen
# Capomulin    4.994774
# Ceftamin     6.268188
# Infubinol    6.567243
# Ketapril     8.279709
# Naftisol     8.134708
# Placebo      7.821003
# Propriva     6.507770
# Ramicane     4.846308
# Stelasyn     7.710419
# Zoniferol    6.966589
# Name: Tumor Volume (mm3), dtype: float64

# %%
sem = combined_df.groupby('Drug Regimen')['Tumor Volume (mm3)'].sem()
sem
# Out:
# Drug Regimen
# Capomulin    0.329346
# Ceftamin     0.469821
# Infubinol    0.492236
# Ketapril     0.603860
# Naftisol     0.596466
# Placebo      0.581331
# Propriva     0.512884
# Ramicane     0.320955
# Stelasyn     0.573111
# Zoniferol    0.516398
# Name: Tumor Volume (mm3), dtype: float64

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary dataframe.
mean = combined_df.groupby('Drug Regimen')['Tumor Volume (mm3)'].mean()
median = combined_df.groupby('Drug Regimen')['Tumor Volume (mm3)'].median()
variance = combined_df.groupby('Drug Regimen')['Tumor Volume (mm3)'].var()
standard_dv = combined_df.groupby('Drug Regimen')['Tumor Volume (mm3)'].std()
sem = combined_df.groupby('Drug Regimen')['Tumor Volume (mm3)'].sem()

summary_df = pd.DataFrame({"Mean": mean, "Median": median, "Variance": variance, "Standard Deviation": standard_dv, "SEM": sem})
summary_df
# Out:
#                    Mean     Median   Variance  Standard Deviation       SEM
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764            4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177            6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684            6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577            8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479            8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083            7.821003  0.581331
# Propriva      52.322552  50.854632  42.351070            6.507770  0.512884
# Ramicane      40.216745  40.673236  23.486704            4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562            7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355            6.966589  0.516398

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Using the aggregation method, produce the same summary statistics in a single line
combined_df.groupby(["Drug Regimen"]).agg({"Tumor Volume (mm3)":["mean", "median","var","std","sem"]}).reset_index()
# Out:
#   Drug Regimen Tumor Volume (mm3)
#                              mean     median        var       std       sem
# 0    Capomulin          40.675741  41.557809  24.947764  4.994774  0.329346
# 1     Ceftamin          52.591172  51.776157  39.290177  6.268188  0.469821
# 2    Infubinol          52.884795  51.820584  43.128684  6.567243  0.492236
# 3     Ketapril          55.235638  53.698743  68.553577  8.279709  0.603860
# 4     Naftisol          54.331565  52.509285  66.173479  8.134708  0.596466
# 5      Placebo          54.033581  52.288934  61.168083  7.821003  0.581331
# 6     Propriva          52.322552  50.854632  42.351070  6.507770  0.512884
# 7     Ramicane          40.216745  40.673236  23.486704  4.846308  0.320955
# 8     Stelasyn          54.233149  52.431737  59.450562  7.710419  0.573111
# 9    Zoniferol          53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using Pandas.
drug_data = pd.DataFrame(combined_df.groupby(["Drug Regimen"]).count()).reset_index()
drugs_df = drug_data[["Drug Regimen", "Mouse ID"]]
drugs_df = drugs_df.set_index("Drug Regimen")

# %%
drugs_df.plot(kind="bar", figsize=(11,5))

plt.title("Drug Treatment Count")
plt.show()
plt.tight_layout()

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using pyplot.

drug_list = summary_df.index.tolist()
drug_list
# Out:
# ['Capomulin',
#  'Ceftamin',
#  'Infubinol',
#  'Ketapril',
#  'Naftisol',
#  'Placebo',
#  'Propriva',
#  'Ramicane',
#  'Stelasyn',
#  'Zoniferol']

# %%
drug_count = (combined_df.groupby(["Drug Regimen"])["Age_months"].count()).tolist()
drug_count
# Out:
# [230, 178, 178, 188, 186, 181, 161, 228, 181, 182]

# %%
x_axis = np.arange(len(drug_count))

# %%
x_axis = drug_list
plt.figure(figsize=(11,5))
plt.bar(x_axis, drug_count, color='blue', alpha=0.5, align="center")

plt.title("Drug Treatment Count")
plt.xlabel("Drug Regimen")
plt.ylabel("Count")
plt.legend("Mouse ID")

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas

gender_df = pd.DataFrame(combined_df.groupby(["Sex"]).count()).reset_index()
gender_df.head()
# Out:
#       Sex  Mouse ID  Drug Regimen  Age_months  Weight (g)  Timepoint  \
# 0  Female       935           935         935         935        935
# 1    Male       958           958         958         958        958
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0                 935               935
# 1                 958               958

# %%
gender_df = gender_df[["Sex","Mouse ID"]]
gender_df.head()
# Out:
#       Sex  Mouse ID
# 0  Female       935
# 1    Male       958

# %%
plt.figure(figsize=(12,6))
ax1 = plt.subplot(121, aspect="equal")
gender_df.plot(kind="pie", y = "Mouse ID", ax=ax1, autopct='%1.3f%%',
              startangle=200, shadow=True, labels=gender_df["Sex"], legend = False, fontsize=16)

plt.title("Male & Female Mice Percentage")
plt.xlabel("")
plt.ylabel("")
# Out:
# Text(0, 0.5, '')

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
gender_count = (combined_df.groupby(["Sex"])["Age_months"].count()).tolist()
gender_count
# Out:
# [935, 958]

# %%
labels = ["Females", "Males"]
colors = ["green", "purple"]
explode = (0.1, 0)

# %%
plt.pie(gender_count, explode=explode, labels=labels, colors=colors, autopct="%1.2f%%", shadow=True, startangle=200)
plt.axis("equal")
# Out:
# (-1.108751137051272,
#  1.1680456474490866,
#  -1.2320970490484973,
#  1.1132964740057565)

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin
combined_df.head()
# Out:
#   Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0     k403     Ramicane  Male          21          16          0
# 1     k403     Ramicane  Male          21          16          5
# 2     k403     Ramicane  Male          21          16         10
# 3     k403     Ramicane  Male          21          16         15
# 4     k403     Ramicane  Male          21          16         20
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           45.000000                 0
# 1           38.825898                 0
# 2           35.014271                 1
# 3           34.223992                 1
# 4           32.997729                 1

# %%
# Start by getting the last (greatest) timepoint for each mouse
#clean_data.sort_value... had no errors but did not print
g_time = combined_df.sort_values(["Drug Regimen", "Mouse ID", "Timepoint"], ascending=True)
last_point = g_time.loc[g_time["Timepoint"] == 45]
last_point.head().reset_index()
# Out:
#    index Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0    309     b128    Capomulin  Female           9          22         45
# 1    299     b742    Capomulin    Male           7          21         45
# 2    244     g288    Capomulin    Male           3          19         45
# 3    360     g316    Capomulin  Female          22          22         45
# 4    440     i557    Capomulin  Female           1          24         45
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           38.982878                 2
# 1           38.939633                 0
# 2           37.074024                 1
# 3           40.159220                 2
# 4           47.685963                 1

# %%
# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
merged_data = last_point.merge(combined_df)
merged_data
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0       b128    Capomulin  Female           9          22         45
# 1       b742    Capomulin    Male           7          21         45
# 2       g288    Capomulin    Male           3          19         45
# 3       g316    Capomulin  Female          22          22         45
# 4       i557    Capomulin  Female           1          24         45
# ..       ...          ...     ...         ...         ...        ...
# 125     p136    Zoniferol  Female           5          28         45
# 126     q511    Zoniferol  Female           2          28         45
# 127     q633    Zoniferol    Male          12          25         45
# 128     s337    Zoniferol    Male          14          27         45
# 129     w575    Zoniferol  Female          16          28         45
#
#      Tumor Volume (mm3)  Metastatic Sites
# 0             38.982878                 2
# 1             38.939633                 0
# ...

# %%
#test
tumor_volume_data = pd.DataFrame()
tumor_volume_data
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
mice_on_each_drug = merged_data.groupby('Drug Regimen').count()
mice_on_each_drug.head()
# Out:
#               Mouse ID  Sex  Age_months  Weight (g)  Timepoint  \
# Drug Regimen
# Capomulin           21   21          21          21         21
# Ceftamin            13   13          13          13         13
# Infubinol            9    9           9           9          9
# Ketapril            11   11          11          11         11
# Naftisol            13   13          13          13         13
#
#               Tumor Volume (mm3)  Metastatic Sites
# Drug Regimen
# Capomulin                     21                21
# Ceftamin                      13                13
# Infubinol                      9                 9
# Ketapril                      11                11
# Naftisol                      13                13

# %%
mice_on_each_drug = merged_data.groupby('Drug Regimen')['Tumor Volume (mm3)'].count()
mice_on_each_drug.head()
# Out:
# Drug Regimen
# Capomulin    21
# Ceftamin     13
# Infubinol     9
# Ketapril     11
# Naftisol     13
# Name: Tumor Volume (mm3), dtype: int64

# %%
moed = merged_data.groupby('Drug Regimen')['Tumor Volume (mm3)']
moed.head()
# Out:
# 0      38.982878
# 1      38.939633
# 2      37.074024
# 3      40.159220
# 4      47.685963
# 21     62.999356
# 22     61.849023
# 23     68.923185
# 24     67.748662
# 25     59.851956
# 34     67.973419
# 35     65.525743
# 36     66.083066
# 37     72.226731
# 38     62.435404
# 43     65.415955
# 44     69.872251
# 45     74.104086
# 46     73.715619
# 47     69.253503
# 54     74.997764
# 55     73.051363
# 56     63.105696
# 57     68.359777
# 58     69.563621
# 67     70.717621
# 68     72.255963
# 69     65.815165
# 70     69.042841
# 71     69.823146
# 78     62.191414
# 79     70.492788
# 80     58.633404
# 81     72.455421
# 82     64.911363
# 85     38.407618
# 86     43.047543
# 87     38.810366
# 88     32.978522
# 89     33.397653
# 105    60.122011
# 106    62.765093
# 107    72.555239
# 108    74.040390
# 109    65.341811
# 116    66.794156
# 117    67.942121
# 118    64.575222
# 119    61.840058
# 120    73.324432
# Name: Tumor Volume (mm3), dtype: float64

# %%
# Put treatments into a list for for loop (and later for plot labels)
four_drug = ['Capomulin', 'Ramicane', 'Infubinol','Ceftamin']

# Create empty list to fill with tumor vol data (for plotting)
tumor_volume_data_df = pd.DataFrame()
#tumor_volume_data = merged_data.DataFrame({'Capomulin': pd.Series([], dtype='float'),
                #   'Ramicane': pd.Series([], dtype='str'),
               #    'Infubinol': pd.Series([], dtype='str'),
                #'Ceftamin':pd.Series([], dtype='str')})

# Calculate the IQR and quantitatively determine if there are any potential outliers. 
quartiles = merged_data["Tumor Volume (mm3)"].quantile([.25,.5,.75])
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq - lowerq
    
# Locate the rows which contain mice on each drug and get the tumor volumes

moed = merged_data.groupby('Drug Regimen')

# add subset 
moed_df = merged_data.groupby('Drug Regimen')['Tumor Volume (mm3)']

#each_drug = clean_data.loc[[0],["Tumor Volume (mm3)"]]
    
# Determine outliers using upper and lower bounds
lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)
outliers_df = merged_data.loc[(merged_data[("Tumor Volume (mm3)")] > upper_bound) | (merged_data[("Tumor Volume (mm3)")] < lower_bound), :]
outliers_df
# Out:
# Empty DataFrame
# Columns: [Mouse ID, Drug Regimen, Sex, Age_months, Weight (g), Timepoint, Tumor Volume (mm3), Metastatic Sites]
# Index: []

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
#Tumor_Volume = merged_data['Tumor Volume (mm3)']
#fig1, ax1 = plt.subplots()
#ax1.set_title('Tumor Volume For Mice')
#ax1.set_ylabel('Tumor Volume')
#ax1.boxplot(Tumor_Volume)
#plt.show()
moed_df = merged_data.groupby('Drug Regimen')["Tumor Volume (mm3)"].apply(list)
tumor_volume_data = pd.DataFrame(moed_df)
moed_df = tumor_volume_data.reindex(four_drug)
tumor_vols = [vol for vol in moed_df["Tumor Volume (mm3)"]]

plt.boxplot(tumor_vols, labels=four_drug,)
plt.ylabel('Tumor Volume')
plt.title('Tumor Volume For Mice')

plt.ylim(20, 80)


plt.show()
#not sure if this is correct. Placement may be off or I misread the instructions.

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin
capomulin_df = clean_data.loc[clean_data["Drug Regimen"] == "Capomulin"]
capomulin_df = capomulin_df.reset_index()
capomulin_df.head()
#tested this only to see if data can be used
# Out:
#    index Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0     10     s185    Capomulin  Female           3          17          0
# 1     20     x401    Capomulin  Female          16          15          0
# 2     30     m601    Capomulin    Male          22          17          0
# 3     60     f966    Capomulin    Male          16          17          0
# 4     95     u364    Capomulin    Male          18          17          0
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0                45.0                 0
# 1                45.0                 0
# 2                45.0                 0
# 3                45.0                 0
# 4                45.0                 0

# %%
capomulin_df = combined_df.loc[combined_df["Drug Regimen"] == "Capomulin"]
capomulin_df = capomulin_df.reset_index()
capomulin_df.head()
# Out:
#    index Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0     10     s185    Capomulin  Female           3          17          0
# 1     11     s185    Capomulin  Female           3          17          5
# 2     12     s185    Capomulin  Female           3          17         10
# 3     13     s185    Capomulin  Female           3          17         15
# 4     14     s185    Capomulin  Female           3          17         20
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           45.000000                 0
# 1           43.878496                 0
# 2           37.614948                 0
# 3           38.177232                 0
# 4           36.866876                 0

# %%
capomulin = capomulin_df.loc[capomulin_df["Mouse ID"] == "f966"]
capomulin
# Out:
#     index Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 30     60     f966    Capomulin  Male          16          17          0
# 31     61     f966    Capomulin  Male          16          17          5
# 32     62     f966    Capomulin  Male          16          17         10
# 33     63     f966    Capomulin  Male          16          17         15
# 34     64     f966    Capomulin  Male          16          17         20
#
#     Tumor Volume (mm3)  Metastatic Sites
# 30           45.000000                 0
# 31           38.796474                 0
# 32           35.624403                 0
# 33           32.623003                 0
# 34           30.485985                 0

# %%
capomulin = capomulin.loc[:, ["Timepoint", "Tumor Volume (mm3)"]]
capomulin = capomulin.reset_index(drop=True)
capomulin.set_index("Timepoint").plot(figsize=(10,8), linewidth=2.5, color="green")
# Out:
# <AxesSubplot:xlabel='Timepoint'>

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen
capomulin_df.head()
# Out:
#    index Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0     10     s185    Capomulin  Female           3          17          0
# 1     11     s185    Capomulin  Female           3          17          5
# 2     12     s185    Capomulin  Female           3          17         10
# 3     13     s185    Capomulin  Female           3          17         15
# 4     14     s185    Capomulin  Female           3          17         20
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           45.000000                 0
# 1           43.878496                 0
# 2           37.614948                 0
# 3           38.177232                 0
# 4           36.866876                 0

# %%
weight_df = capomulin_df.loc[:, ["Mouse ID", "Weight (g)", "Tumor Volume (mm3)"]]
weight_df.head()
# Out:
#   Mouse ID  Weight (g)  Tumor Volume (mm3)
# 0     s185          17           45.000000
# 1     s185          17           43.878496
# 2     s185          17           37.614948
# 3     s185          17           38.177232
# 4     s185          17           36.866876

# %%
capomulin_average = pd.DataFrame(weight_df.groupby(["Mouse ID", "Weight (g)"])["Tumor Volume (mm3)"].mean()).reset_index()
capomulin_average.head()
# Out:
#   Mouse ID  Weight (g)  Tumor Volume (mm3)
# 0     b128          22           41.963636
# 1     b742          21           40.083699
# 2     f966          17           36.505973
# 3     g288          19           41.990097
# 4     g316          22           44.613344

# %%
capomulin_average = capomulin_average.rename(columns={"Tumor Volume (mm3)": "Average Volume"})
capomulin_average.head()
# Out:
#   Mouse ID  Weight (g)  Average Volume
# 0     b128          22       41.963636
# 1     b742          21       40.083699
# 2     f966          17       36.505973
# 3     g288          19       41.990097
# 4     g316          22       44.613344

# %%
capomulin_average.plot(kind="scatter", x="Weight (g)", y="Average Volume", grid=True, figsize=(6,6), title="Weight vs. Average Tumor Volume")
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
